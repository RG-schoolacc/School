# %% [markdown]
# <a href="https://colab.research.google.com/github/RG-schoolacc/School/blob/main/HW1GARTLEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Roy Gartley Homework 1
#created github acc RG-schoolacc
import pandas as pd
medals = pd.read_csv('/content/drive/MyDrive/DATA/olympic_medals.csv')

# %% [markdown]
# Finding the size of the dataset

# %%
print('Rows','Columns')
print(medals.shape)
# Out:
# Rows Columns
# (2394, 8)

# %%
print('More discription including data type')
print(medals.info())
#another way
print(medals.dtypes)
# Out:
# More discription including data type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2394 non-null   object
#  2   Location     2394 non-null   object
#  3   Year         2394 non-null   int64
#  4   Medal        2394 non-null   object
#  5   Name         2164 non-null   object
#  6   Nationality  2394 non-null   object
#  7   Result       2351 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 149.8+ KB
# None
# Gender         object
# Event          object
# Location       object
# Year            int64
# Medal          object
# Name           object
# Nationality    object
# Result         object
# dtype: object

# %% [markdown]
# C Find how many unique cities matches were held at. (Hint: unique( ). For instance, the following example tells
# how many unique Events held:)
# len(medals['Event'].unique())

# %%
print(medals["Location"].unique())
print(len(medals["Location"].unique()))
#I was checking how many unique nationalities there are to check part e
#len(medals["Nationality"].unique())
# Out:
# ['Rio' 'Beijing' 'Sydney' 'Barcelona' 'Los Angeles' 'Montreal' 'Mexico'
#  'Rome' 'Helsinki' 'Berlin' 'Amsterdam' 'Antwerp' 'London' 'Athens'
#  'Atlanta' 'Moscow' 'Munich' 'Tokyo' 'Melbourne / Stockholm' 'Paris'
#  'Stockholm' 'St Louis' 'Seoul']
# 23

# %% [markdown]
# (d) Find how many medals the USA team won in total.

# %%
num = medals[medals['Nationality']=='USA'].shape[0]
print(num)
# Out:
# 638

# %% [markdown]
# (e) Find the total number of medals for each Nationality. (Hint: please search for groupby() function with count.
# For instance, the following example counts at how many locations each event was held. )
# medals.groupby(by='Event')['Location'].count()

# %%
mpn=medals.groupby(by='Nationality')['Medal'].count()
print(mpn.to_string())
# Out:
# Nationality
# ALG      9
# ARG      4
# AUS     57
# AUT      4
# BAH     12
# BAR      1
# BDI      2
# BEL     12
# BLR     14
# BOT      1
# BRA     10
# BRN      3
# BUL     12
# BWI      2
# CAN     53
# CHI      1
# CHN     23
# CIV      1
# CMR      2
# COL      3
# CRO      5
# CUB     40
# CZE     12
# DEN      6
# DJI      1
# DOM      3
# ECU      2
# ERI      1
# ESP     14
# EST      6
# ETH     53
# EUA     26
# EUN     18
# FIN     74
# FRA     60
# FRG     28
# GBR    161
# GDR     76
# GER     74
# GRE     23
# GRN      2
# GUA      1
# HAI      1
# HUN     30
# IND      1
# IRI      1
# IRL      6
# ISL      1
# ITA     46
# JAM     74
# JPN     20
# KAZ      4
# KEN     87
# KOR      2
# KSA      1
# LAT      5
# LTU      5
# LUX      1
# MAR     17
# MEX     11
# MOZ      2
# NAM      4
# NED     14
# NGR     13
# NOR     15
# NZL     24
# PAN      3
# PHI      2
# POL     52
# POR     10
# PUR      1
# QAT      3
# ROU     29
# RSA     26
# RUS     62
# ...
